# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'buddhikaeranga', 'key': 'c3222f13af7d9b72409a26eb6be2c8c5'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-2.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: bleach in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from kaggle) (6.3.0)
# Collecting kagglesdk<1.0,>=0.1.15 (from kaggle)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from kaggle) (26.0)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from kaggle) (2.32.5)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from requests->kaggle) (2026.1.4)
# Requirement already satisfied: colorama in g:\free ai course\ml project\sentiment-analysis-project\env\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-2.0.0-py3-none-any.whl (75 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Downloading protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kagglesdk, kaggle
#
#    ---------------------------------------- 0/6 [text-unidecode]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------ --------------------------------- 1/6 [tqdm]
#    ------------- -------------------------- 2/6 [python-slugify]
#    ------------- -------------------------- 2/6 [python-slugify]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------- ------------------- 3/6 [protobuf]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    --------------------------------- ------ 5/6 [kaggle]
#    ---------------------------------------- 6/6 [kaggle]
#
# Successfully installed kaggle-2.0.0 kagglesdk-0.1.15 protobuf-6.33.5 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.3
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip','r') as zip_ref:
    zip_ref.extractall('../artifacts')
